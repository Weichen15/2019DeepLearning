# %%
import numpy as np
import pandas as pd

# %%
y_train = pd.read_csv("/Users/jianweicheng/Desktop/ＮＴＵＴ/碩二上/深度學習/assignment/02_Assignment/data/Train.csv")

# %%
y_train.head()
# Out:
#       x1_10      x1_9      x1_8      x1_7      x1_6      x1_5      x1_4  \
# 0  0.296808  0.632320  0.495099  0.558432  0.656572  0.370696  0.621890
# 1  0.739884  0.663358  0.604549  0.642247  0.489445  0.480774  0.444710
# 2  0.509927  0.685474  0.507540  0.476250  0.499874  0.470596  0.622644
# 3  0.537824  0.490953  0.325584  0.361146  0.461297  0.433526  0.559814
# 4  0.466575  0.593868  0.621513  0.549133  0.379367  0.624529  0.346569
#
#        x1_3      x1_2      x1_1  ...      x2_9      x2_8      x2_7      x2_6  \
# 0  0.511184  0.511812  0.248932  ...  0.447966  0.454233  0.452497  0.438392
# 1  0.599522  0.343428  0.272179  ...  0.574430  0.566882  0.554571  0.561540
# 2  0.472104  0.761247  0.435537  ...  0.586513  0.591203  0.599842  0.605502
# 3  0.774943  0.713245  0.491958  ...  0.279338  0.306992  0.330160  0.340693
# 4  0.560568  0.614853  0.625031  ...  0.315910  0.306222  0.305670  0.326542
#
#        x2_5      x2_4      x2_3      x2_2      x2_1  y
# ...

# %%
y_train = y_train['y']

# %%
y_tr = pd.DataFrame(y_train)
y_tr.to_csv("/Users/jianweicheng/Desktop/ＮＴＵＴ/碩二上/深度學習/assignment/03_Assignment/y_train.csv", index = 0)

# %%
y_test = pd.read_csv("/Users/jianweicheng/Desktop/ＮＴＵＴ/碩二上/深度學習/assignment/02_Assignment/data/Test.csv")
y_test = y_test['y']
y_t = pd.DataFrame(y_test)
y_t.to_csv("/Users/jianweicheng/Desktop/ＮＴＵＴ/碩二上/深度學習/assignment/03_Assignment/y_test.csv", index = 0)
